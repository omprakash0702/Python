# %% [markdown]
#         Data Science: A Programming Approach

# %% [markdown]
# <h1 align='center' style="color: blue;">Assignment #1</h1>

# %% [markdown]
# <b> Question 1:</b> In this question, you need to use a package called `emoji` in your work. To do so, run the following lines of code to install and import the package into your environment.

# %%
# install the package
# !python -m pip install emoji
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: emoji in c:\users\sachi\appdata\roaming\python\python39\site-packages (2.2.0)

# %%
# import the package
import emoji

# %% [markdown]
# Now consider the following list:

# %%
emoji_list = [':slightly_smiling_face:',':pensive_face:',':disguised_face:',
              ':headphone:',':astonished_face:',':hamburger:',':grinning_face_with_smiling_eyes:',
              ':panda:',':fearful_face:',':loudly_crying_face:']

# %% [markdown]
# The preceding list contains a list of codes that represent various emojis. Using the `emojize` function, you can see the actual emoji. Here's an example:

# %%
for item in emoji_list:
    print(item,'-->',emoji.emojize(item))
# Out:
# :slightly_smiling_face: --> 🙂
# :pensive_face: --> 😔
# :disguised_face: --> 🥸
# :headphone: --> 🎧
# :astonished_face: --> 😲
# :hamburger: --> 🍔
# :grinning_face_with_smiling_eyes: --> 😄
# :panda: --> 🐼
# :fearful_face: --> 😨
# :loudly_crying_face: --> 😭

# %% [markdown]
# Your task is to perform following parts:
# <ol>
#     <li><b>Part #1:</b>
#         <ul>
#         <li>Use the <i>input</i> function to show each of the above emojis to a user and ask her to provide 5 words that describe the emoji. The user should provide 5 single word separated by ';' to describe the emoji. <b>For example:</b> "Happy;Nice; smile;happy ;cheers "</li>
#         <li>After receiving the user's input, you must divide the string into a list of five items, remove any possible white space around the words, and convert all of them to lowercase.<b>For example: </b>the above input should converted into ['happy','nice','smile','happy','cheers'] </li>
#         <li>Convert the list to a set to eliminate any possible duplicates.  <b>For example: </b>the above set should converted into {'happy','nice','smile','cheers'}
#         </li>
#         <li>Make a dictionary that associates each emoji code with a set of words provided by the user as a descriptor for that emoji. In doing so, you need to use the emoji code as the key and the identified set as the value. <b>For example: </b> {':slightly_smiling_face:':{'happy','nice','smile','cheers'}}
#          </li>
#             <li>Using the iterative structure, add one set to the dictionary for each emoji code.</li>
#         </ul>
#     <li><b>Part #2:</b> Use the pickle package to save the dictionary you created in the previous section to a data file.</li>
#     <li><b>Part #3:</b> Load the saved data to a new variable named <i>emoji_dict</i>.</li>
#     <li><b>Part #4:</b> Prompt the user to write a sentence containing some of the words she used to describe the emojis. Add the associated emoji to the sentence right after the word that describe the emoji and print it for the user <b>For example: </b> If the user inputs "I'm so happy today", your code should print "I'm so happy 🙂 today."</li>
#
# </ol>

# %%
# Write part #1 code here
emoji_descriptors = {}

for emoji_code in emoji_list:
    emoji_char = emoji.emojize(emoji_code)
    user_input = input(f"Describe the emoji in 5 words{emoji_char}: ")
    
    # Convert the user input to a list of words, lowercase, and remove white spaces
    words = [word.strip().lower() for word in user_input.split(';')]
    
    # Convert the list to a set to eliminate duplicates
    words_set = set(words)
    
    # Add the set of words to the dictionary with emoji code as the key
    emoji_descriptors[emoji_code] = words_set

print("Emoji Descriptors:")
print(emoji_descriptors)
# Out:
# Describe the emoji in 5 words🙂: happy;nice;smile;cheers;fine
# Describe the emoji in 5 words😔: sad;pensive;not good;unlucky; broken
# Describe the emoji in 5 words🥸: what;question;why;how;
# Describe the emoji in 5 words🎧: vibing;music;Headphone;music;song
# Describe the emoji in 5 words😲: ohh!;what;what the hell;why;oooo!
# Describe the emoji in 5 words🍔: burger;lazy;fatty;cheese_burger
# Describe the emoji in 5 words😄: its_ok;its_fine;no_problem;small_laugh,very_happy
# Describe the emoji in 5 words🐼: panda;lazy;idiot;cute;panda
# Describe the emoji in 5 words😨: astonished;surprised;shock;how?;oh no
# Describe the emoji in 5 words😭: crying;very broken;in pain
# Emoji Descriptors:
# {':slightly_smiling_face:': {'fine', 'cheers', 'happy', 'nice', 'smile'}, ':pensive_face:': {'broken', 'sad', 'pensive', 'not good', 'unlucky'}, ':disguised_face:': {'', 'question', 'how', 'what', 'why'}, ':headphone:': {'vibing', 'music', 'song', 'headphone'}, ':astonished_face:': {'what the hell', 'what', 'oooo!', 'why', 'ohh!'}, ':hamburger:': {'fatty', 'burger', 'lazy', 'cheese_burger'}, ':grinning_face_with_smiling_eyes:': {'its_ok', 'no_problem', 'its_fine', 'small_laugh,very_happy'}, ':panda:': {'idiot', 'cute', 'panda', 'lazy'}, ':fearful_face:': {'surprised', 'shock', 'astonished', 'oh no', 'how?'}, ':loudly_crying_face:': {'very broken', 'in pain', 'crying'}}

# %%
# Write part #2 code here
import pickle

# Saving the dictionary to a data file using pickle
with open('emoji_descriptors.pickle', 'wb') as file:
    pickle.dump(emoji_descriptors, file)

print("Dictionary saved to emoji_descriptors.pickle")
# Out:
# Dictionary saved to emoji_descriptors.pickle

# %%
# Write part #3 code here
# Loading the data from the pickle file
with open('emoji_descriptors.pickle', 'rb') as file:
    emoji_dict = pickle.load(file)

print("Dictionary loaded successfully.")
# Out:
# Dictionary loaded successfully.

# %%
# Write part #4 code here
import emoji

# Prompt user for a sentence
sentence = input("Write a sentence: ")

# Iterate over the emoji descriptors
for emoji_code, descriptors in emoji_dict.items():
    for descriptor in descriptors:
        # Check if the descriptor word is present in the sentence
        if descriptor in sentence:
            # Get the corresponding emoji character
            emoji_char = emoji.emojize(emoji_code)
            
            # Replace the descriptor word with the descriptor word + emoji character
            sentence = sentence.replace(descriptor, f"{descriptor} {emoji_char}", 1)

print("Modified sentence:", sentence)
# Out:
# Write a sentence: broken burger made you sad
# Modified sentence:  🥸broken 😔 burger 🍔 made you sad 😔

# %% [markdown]
# <p><b>Question #2</b>:
#
# Your task is to create a simple encryption method. In your encryption process, you must replace each character in a sentence with the corresponding character in the encryption list. Consider the following string files in your work:

# %%
alp_string = 'abcdefghijklmnopqrstuvwxyz'
enc_string = 'wxyzabcdefghijklmnopqrstuv'

# %% [markdown]
# The `alp_string` shows the sequance of alphabet characters. The `enc_string` shows the corresponding encrpytion characters. For example, in this sequance, the character 'a' should be replaced by 'w' and the character 'b' should be replaced by 'x' and so on.

# %% [markdown]
# <ol>
#     <li> Write a small python function <b>string_to_list</b> that converts a string to a list of characters.</li>
#     <li> Convert alp_string to alp_list.</li>
#     <li> Convert enc_string to enc_list.</li>
#     <li> Build a dictionary named <b>enc_dict</b> in which each character in alp_list becomes a key and the corresponding character in enc_list becomes the value ( Here is the expcted out put that shows first two elements in the dictionary :{'a':'w', 'b':'x', ...}).<b>Tip:</b> Use zip function along with comprehension to achieve this task</li>
#     <li>Write a function named <b>encryption</b> that uses enc_dict to convert an input string to its encrypted version of it and return the encrypted string.(<b>Important:</b> Since your dictionary contains only lower case characters, make sure that your function converts the input string to a lower case string at the very first step.)</li>
#     <li>Write lines of code that asks the user to input a text message. Then use the encryption function that you've developed in the last step to find the encrypted version of the text message.</li>
#         <p><b>Here is an example:</b></p>
#         <p>Please input a message: 'this is a test message to test encyption.'</p>
#         <p>Your encrypted message is: 'pdeo eo w paop iaoowca pk paop ajyulpekj.'</p>
# </ol>

# %%
# Write your answer here (part1)
def string_to_list(input_string):
    return list(input_string)

# %%
# Write your answer here (part2)
alp_list = string_to_list(alp_string)

# %%
# Write your answer here (part3)
enc_list = string_to_list(enc_string)

# %%
# Write your answer here (part4)
enc_dict = {alp: enc for alp, enc in zip(alp_list, enc_list)}

# %%
# Write your answer here (part5)
def encryption(input_string, enc_dict):
    # Convert input string to lowercase
    input_string = input_string.lower()
    
    # Convert each character of input string to its corresponding encrypted character
    encrypted_string = ''.join(enc_dict.get(char, char) for char in input_string)
    
    return encrypted_string

# %%
# Write your answer here (part6)
# Prompt user for a text message
text_message = input("Enter your text message: ")

# Call the encryption function to get the encrypted version
encrypted_message = encryption(text_message, enc_dict)

# Print the encrypted message
print("Encrypted Message:", encrypted_message)
# Out:
# Enter your text message: this is a test message to test encyption
# Encrypted Message: pdeo eo w paop iaoowca pk paop ajyulpekj

# %% [markdown]
# <p><b>Question #3</b>: Consider the previous example and write a decryption function.
# <ol>
#     <li>Build your function and test it with a simple input</li>
#     <p><b>Here is a simple example:</b></p>
#     <p>Input: 'pdeo eo w paop iaoowca pk paop ajyulpekj.'</p>
#     <p>Output: 'this is a test message to test encyption.'</p>
#     <p>&nbsp;</p>
#     <li>What is the output of this message?</li>
#     <p>Input: 'pdeo eo w dezzaj iaoowca; kjya zaykzaz, ck pk ywjrwo wjz lkop ej pda laan zeoyqooekj xkwnz: dks awou pda wooecjiajp eo.'</p>
# </ol>
# </p>

# %%
# Write your answer here (part1)
dec_dict = {enc: alp for enc, alp in zip(enc_list, alp_list)}

def decryption(input_string, enc_dict):
    # Convert each character of the encrypted string to its corresponding decrypted character
    decrypted_string = ''.join(dec_dict.get(char, char) for char in input_string)
    
    return decrypted_string

# %%
text_message = input("Enter your text message: ")

# Call the encryption function to get the encrypted version
decrypted_message = decryption(text_message, enc_dict)

# Print the encrypted message
print("Decrypted Message: of ",text_message," is ", decrypted_message)

# %%
# Write your answer here (part2)
for i in range(2):
    text_message = input("Enter your text message: ")
    decrypted_message = decryption(text_message, enc_dict)
    print("Decrypted Message:", decrypted_message)
# Out:
# Enter your text message: pdeo eo w dezzaj iaoowca
# Decrypted Message: this is a hidden message
# Enter your text message: kjya zaykzaz, ck pk ywjrwo wjz lkop ej pda laan zeoyqooekj xkwnz: dks awou pda wooecjiajp eo
# Decrypted Message: once decoded, go to canvas and post in the peer discussion board: how easy the assignment is

# %% [markdown]
# <p><b>Question #4</b>:<br>
#
# Consider the follwing line of codes:

# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

Greece_image = np.array(mpimg.imread('Greece.jpg'))
fig, ax = plt.subplots(figsize=(12, 18))
ax.imshow(Greece_image)
ax.set(xticks=[], yticks=[])

plt.show()

# %%
Greece_image.shape
# Out:
# (3371, 5056, 3)

# %% [markdown]
# As you know `Greece_image` is a 3 dimensional Numpy array. With that consideration, answer the following questions:
#
# <ol>
#     <li>Copy the Greece_image to a new numpy array named New_Greece_Image. Add a value of 50 to all cells in the Blue channel of New_Greece_Image that have a value of less than 200. Visualize the new image.</li>
#     <li>Make all the values in the New_Greece_Image's Green channel equal to 0. Visualize the new image. (You don't need to create a new copy. Just use the same updated array for the last step)</li>
#     <li> Use Greece_image array and apply the mean aggregation function to find the average of values across different channels. Put the result in new array named New_Greece_Gray_Scale. (<b>Tip:</b> The shape of the output array (New_Greece_Gray_Scale) should be equal to (3371, 5056)). Visualize the New_Netherlands_Gray_Scale.</li>
#     <li>Copy the Greece_image to a new numpy array named Greece_Image_Colorful. Modify the Greece_Image_Colorful array in such a way that you have only the Blue channel on the top half of the image and only the Green channel on the bottom half of the image. Visualize the result.</li>
#  </ol>

# %%
# Write your answer here (part1)
New_Greece_Image = Greece_image.copy()
blue_channel = New_Greece_Image[:, :, 2]  # Blue channel is the third dimension (index 2)

# Add 50 to cells in the Blue channel that have a value less than 200
blue_channel[blue_channel < 200] += 50

# Visualize the new image
fig, ax = plt.subplots(figsize=(12, 18))
ax.imshow(New_Greece_Image)
ax.set(xticks=[], yticks=[])
plt.show()

# %%
# Write your answer here (part2)
New_Greece_Image[:, :, 1] = 0  # Set all values in the Green channel to 0

# Visualize the new image
fig, ax = plt.subplots(figsize=(12, 18))
ax.imshow(New_Greece_Image)
ax.set(xticks=[], yticks=[])
plt.show()

# %%
# Write your answer here (part3)
New_Greece_Gray_Scale = np.mean(Greece_image, axis=2, keepdims=True)

# Visualize the New_Greece_Gray_Scale
fig, ax = plt.subplots(figsize=(12, 18))
ax.imshow(New_Greece_Gray_Scale[:, :, 0], cmap='gray')
ax.set(xticks=[], yticks=[])
plt.show()

# %%
# Write your answer here (part4)
Greece_Image_Colorful = Greece_image.copy()

# Get the dimensions of the image
height, width, _ = Greece_Image_Colorful.shape

# Modify the image to display only Blue channel on top half and Green channel on bottom half
Greece_Image_Colorful[:height//2, :, [1, 2]] = 0  # Set Green and Red channels to 0 on top half
Greece_Image_Colorful[height//2:, :, [0, 2]] = 0  # Set Blue and Red channels to 0 on bottom half

# Visualize the modified image
fig, ax = plt.subplots(figsize=(12, 18))
ax.imshow(Greece_Image_Colorful)
ax.set(xticks=[], yticks=[])
plt.show()

# %% [markdown]
# <p><b>Question #5</b>:<br>
# <ol>
# <li> Create a 6x5 random matrix (matrix A) using a normal distribution with mean = -1.2 and std = .4 </li>
# <li> Create another 5x3 matrix in the following format: (matrix B)
# <br>
# <br>
# <div>
# <table style="width:200px; border:1px solid black">
# <tr>
#     <td style="text-align:center; border:1px solid black">0</td>
#     <td style="text-align:center; border:1px solid black">-1</td>
#     <td style="text-align:center; border:1px solid black">-1</td>
# </tr>
# <tr>
#     <td style="text-align:center; border:1px solid black">3</td>
#     <td style="text-align:center;border:1px solid black">4</td>
#     <td style="text-align:center;border:1px solid black">1</td>
# </tr>
# <tr>
#     <td style="text-align:center; border:1px solid black">-1</td>
#     <td style="text-align:center; border:1px solid black">2</td>
#     <td style="text-align:center;border:1px solid black">3</td>
# </tr>
# <tr>
#     <td style="text-align:center; border:1px solid black">2</td>
#     <td style="text-align:center; border:1px solid black">4</td>
#     <td style="text-align:center; border:1px solid black">3</td>
# </tr>
# <tr>
#     <td style="text-align:center;border:1px solid black">2</td>
#     <td style="text-align:center;border:1px solid black">0</td>
#     <td style="text-align:center;border:1px solid black">-2</td>
# </tr>
# </table>
# <div></li>
# <br>
# <li> Find Dot Product of matrix A and B and put it in matrix C.</li>
# <li> Find the row wise sum of the matrix C.</li>
# </p>

# %%
# Write your answer here (part1)
import numpy as np

mean = -1.2
std = 0.4

A = np.random.normal(mean, std, size=(6, 5))

print("Matrix A:")
print(A)
# Out:
# Matrix A:
# [[-1.02054789 -1.52777987 -1.44767144 -1.55620087 -1.7724545 ]
#  [-0.98867126 -0.69457281 -0.79778268 -1.00572283 -1.2274907 ]
#  [-1.4399376  -1.03793534 -1.46881359 -1.03093518 -1.79175755]
#  [-1.09252875 -0.97724582 -1.33955332 -2.0396373  -1.46756063]
#  [-2.2052444  -0.73855401 -1.23261941 -1.19785383 -0.86578628]
#  [-1.66280033 -1.60483223 -1.60328222 -1.35063659 -1.25591052]]

# %%
# Write your answer here (part2)
B_elements = [[0, -1, 1], [3, 4, 1], [-1, 2, 3], [2, 4, 3], [2, 0, -2]]
B = np.array(B_elements)

print("Matrix B:")
print(B)
# Out:
# Matrix B:
# [[ 0 -1  1]
#  [ 3  4  1]
#  [-1  2  3]
#  [ 2  4  3]
#  [ 2  0 -2]]

# %%
# Write your answer here (part3)
C = np.dot(A, B)

print("Matrix C:")
print(C)
# Out:
# Matrix C:
# [[ -9.79297892 -14.21071797  -8.01503571]
#  [ -5.75236281  -7.40807667  -4.63877922]
#  [ -7.29037789  -9.77317163  -6.39360412]
#  [ -8.60657999 -13.65411035  -9.27222516]
#  [ -5.11032283  -8.00562576  -8.50364556]
#  [ -8.42430869 -13.3656394   -9.61756795]]

# %%
# Write your answer here (part4)
row_sum = np.sum(C, axis=1)

print("Row-wise sum of matrix C:")
print(row_sum)
# Out:
# Row-wise sum of matrix C:
# [-32.0187326  -17.79921871 -23.45715365 -31.53291551 -21.61959415
#  -31.40751605]

# %% [markdown]
# <p><b>Question #6</b>:<br>
# <ol>
#     <li> Use pandas read_csv( ) function to read the BlackFriday.csv file - You can find the csv file in Canvas. (<b>Note:</b> This is a dataset available in Kaggle. It is a dataset of 550000 observations about the black Friday in a retail store, it contains different kinds of variables either numerical or categorical. It contains missing values.)</li>
# <li> Find the number of male and female in this dataset.
#     <ul><li>To do so, you must first create a separate dataset containing User ID, Gender, and Age.</li>
#     <li>Name the new dataset as customer_dataset.</li>
#     <li>Remove duplicate rows from the customer_dataset.</li>
#     <li>Use the group by method to find the number of males and females in the dataset.</li>
#     </ul>
#  </li>
#
# <li> Find the average purchase amount by individuals' gender
#     <ul>
#         <li>Again, you must first aggregate the purchase amount at the user level (sum) before determining it at the gender level.</li>
#     </ul>
#  </li>
#
# <li> Find the maximum purchase amount by age and city category and sort the result by the maximum purchase amount (ascending) </li>
# <li> Find the minimum purchase amount by gender and marital status and sort the result by the minimum purchase amount (descending) </li>
# </p>

# %%
# Write your answer here (part1)
import pandas as pd
df=pd.read_csv('BlackFriday.csv')
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 537572                          1               0                   1
# 537573                          1               0                   1
# 537574                          1               0                   8
# 537575                          1               0                   5
# 537576                          1               0                   5
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN      8370
# 1                      6.0                14.0     15200
# 2                      NaN                 NaN      1422
# 3                     14.0                 NaN      1057
# 4                      NaN                 NaN      7969
# ...                    ...                 ...       ...
# 537572                 2.0                 NaN     11664
# 537573                15.0                16.0     19196
# 537574                15.0                 NaN      8043
# 537575                 NaN                 NaN      7172
# 537576                 8.0                 NaN      6875
#
# [537577 rows x 12 columns]

# %%
# Write your answer here (part2)
customer_dataset = df[['User_ID', 'Gender', 'Age']]
customer_dataset.drop_duplicates(inplace=True)
gender_counts = customer_dataset.groupby('Gender').size()
print(gender_counts)
# Out:
# Gender
# F    1666
# M    4225
# dtype: int64
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_20016\3721322930.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customer_dataset.drop_duplicates(inplace=True)

# %%
# Write your answer here (part3)
user_purchase = df.groupby('User_ID')['Purchase'].sum()
merged_dataset = pd.merge(customer_dataset, user_purchase, left_on='User_ID', right_index=True)
average_purchase_by_gender = merged_dataset.groupby('Gender')['Purchase'].mean()
print(average_purchase_by_gender)
# Out:
# Gender
# F    699054.034214
# M    911963.161420
# Name: Purchase, dtype: float64

# %%
# Write your answer here (part4)
max_purchase_by_age_city = df.groupby(['Age', 'City_Category'])['Purchase'].max()
sorted_max_purchase = max_purchase_by_age_city.sort_values(ascending=True)
print(sorted_max_purchase)
# Out:
# Age    City_Category
# 0-17   A                23847
# 46-50  A                23912
# 55+    A                23913
# 46-50  C                23919
# 36-45  A                23949
#        C                23949
# 18-25  C                23952
# 0-17   B                23953
# 55+    B                23954
# 0-17   C                23955
# 26-35  B                23955
# 18-25  A                23958
#        B                23958
# 51-55  C                23958
#        B                23959
# 36-45  B                23960
# 46-50  B                23960
# 51-55  A                23960
# 55+    C                23960
# 26-35  C                23961
#        A                23961
# Name: Purchase, dtype: int64

# %%
# Write your answer here (part5)
min_purchase_by_gender_marital = df.groupby(['Gender', 'Marital_Status'])['Purchase'].min()
sorted_min_purchase = min_purchase_by_gender_marital.sort_values(ascending=False)
print(sorted_min_purchase)
# Out:
# Gender  Marital_Status
# M       1                 187
# F       1                 186
#         0                 185
# M       0                 185
# Name: Purchase, dtype: int64
